# %% [markdown]
# # MATOPE v2.1
# ## Generador de Operaciones Matemáticas en hojas de cálculo, con ayudas para su resolución.
#
# Instrucciones:
# 1.   Rellena, más abajo,  las casillas de parámetros(**Nombre_de_la_Hoja_Excel** y **Lista_de_operaciones**) <br> y opcionalmente los Parámetros Secundarios
# 2.   Para ejecutar el programa: (3 opciones)
#      - Pulsa **Ctrl+Enter**
#      - Haz Click en el pequeño boton "play" (triangulito) debajo de Parámetros
#      - o en el menu superior elige :**Entorno de ejecución** -> **Ejecutar Todas**
# 3.   El fichero excel  se descargará automáticamente.

# %%
# @title Parámetros  {"display-mode":"form"}

# @markdown ### **PARÁMETROS PRINCIPALES**
# @markdown ---

Nombre_de_la_hoja_Excel = "Divisiones_Javi999" # @param {"type":"string","placeholder":"Introduce el nombre del fichero"}
# @markdown    ######          `Ejemplos : Sumas_y_Multiplicaciones_Juan`<br>  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`Operaciones_3PRIMARIA`
# @markdown ---
Lista_de_operaciones = "2456/2    3578:3   5678:4    8932/5 14+11+27+28" # @param {"type":"string","placeholder":"Introduce la lista de operaciones (+ - * :) separadas por espacios"}
# @markdown >- Separar las operaciones con espacios
# @markdown >- Las operaciones permitidas son `+ -  *  :  /`
# @markdown <br> ( **`/`** -> **DIVISION CON RESTAS AUXILIARES**, `:` -> división sin restas )
# @markdown >-(las sumas puede tener más de 2 sumandos)

# @markdown    ######       ```Ejemplos : 2345+3344 234/3 234:3 28*4 126-13 23+34+16+1```<br>  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;```162+5 278-18 150:5```

# @markdown ---

# @markdown <br>

# @markdown ### **MODOS DE RESOLUCIÓN**
# @markdown ---


Modos_de_Resolucion_Disponibles = "Fácil,Pro,SuperPro" # @param ["Fácil,Pro,SuperPro","Pro,SuperPro","Fácil","Pro","SuperPro"]
# @markdown Son los modos que el estudiante pordra elegir cuando esté resolviendo las operaciones:<br>
# @markdown >- **Fácil** &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;-> Cambian de color las respuestas intermedias correctas y la final completa.
# @markdown >- **Pro**&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;  -> Sólo cambia de color la respuesta final completa y correcta.
# @markdown >- **SuperPro** -> El estudiante no tiene feedback

# @markdown    ######          `Ejemplos :"Fácil,Pro,SuperPro"` (el estudiante podra elegir cualquier modo)<br>  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;```"Pro"``` (el estudiante sólo tendra disponible el modo Pro)

# @markdown ---
Modo_Inicial_Seleccionado = "Fácil" # @param ["Fácil","Pro","SuperPro"]
# @markdown Es el modo de resolución con el que se abrirá la hoja de cálculo inicialmente.<br>

# @markdown    ######          `Ejemplo :"Fácil"` (El estudiante empezará en modo Fácil. Podra cambiar de modo , si tiene otros disponibles.)

# @markdown ---

# @markdown <br>

# @markdown ### **TAMAÑOS / DISPOSICIÓN DE OPERACIONES**
# @markdown ---
Tamano_tipo_de_letra = 26 # @param {"type":"number","placeholder":"Introduce el tamaño de la fuente de texto"}
# @markdown    ######          `Ejemplos : 26` (grande) <br>  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;```11``` (pequeña)
# @markdown ---
Numero_de_columnas_de_operaciones = 4 # @param {"type":"number","placeholder":"Introducir el numero de columnas de operaciones en la hoja de cálculo"}
# @markdown    ######          `Ejemplo :4` (Las operaciones de la hoja de calculo se distribuiran en 4 columnas.)
# @markdown ---
Lineas_de_restas_auxiliares_en_divisiones_siempre_visibles = False # @param {"type":"boolean","placeholder":"Si chequeada las lineas auxiliares de las restas de las divisiones seran siempre visibles"}
# @markdown    ######          `Ejemplo :Sin marcar`, las lineas auxiliares de las restas de las divisiones irán apareciendo conforme se resuelva la división
# @markdown ---
Minimo_celdas_por_operacion = 4 # @param {"type":"number","placeholder":"Introducir el mínimo numero de celdas que ocupara cada operacion en la hoja"}
# @markdown    ######          `Ejemplo :4` (Las operaciones ocuparan un cuadrado de al menos 4x4 celdas en las hoja)<br>  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; (sirve para dejar un espacio mayor, del calculado por defecto,entre las operacione en la hoja )





# @markdown ---

# @markdown <br>

# @markdown ### **COLORES**
# @markdown Los colores se definen con su código HEX RGB de **6 carácteres**.<br>

# @markdown    ######          `Ejemplos :000000`(Negro) , `FFFFFF`(Blanco) , `FF0000`(Rojo) , `00FF00`(Verde) , `0000FF`(Azul) , `FFFF00`(Amarillo) , `FF00FF`(Magenta) , `00FFFF`(Cian)
# @markdown [Haz click para ver códigos de color](https://docs.google.com/spreadsheets/d/1f_wY2Ph9XxWk55XhJ4GRHpHxnWGqJCsFcFcc_5SPlNg/edit?usp=sharing)
# @markdown  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;   [Más códigos de colores](https://www.rapidtables.com/web/color/RGB_Color.html)

# @markdown ---



Color_Respuesta_Final_Correcta = "2EFE2E" # @param {"type":"string","placeholder":"Introduce el color de las soluciones de las operaciones (codigo de color HEX RGB)"}
# @markdown Es el color al que cambiaran las soluciones completas cuando sean correctas.<br>

# @markdown    ######          `Ejemplos :2EFE2E`(dark green)<br>  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;```00FFFF``` (blue)




# @markdown ---
Color_Respuesta_Intermedia_Correcta = "04B431" # @param {"type":"string","placeholder":"Introduce el color de las operaciones intermedias correctas (codigo de color HEX RGB)"}
# @markdown Es el color al que cambiaran las respuestas intermedias cuando sean correctas.<br>

# @markdown    ######          `Ejemplos :04B431`(green)<br>  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;```B3648F``` (dark magenta 1)

# @markdown ---
Color_Respuesta_Intermedia_Incorrecta = "FF0000" # @param {"type":"string","placeholder":"Introduce el color de las operaciones intermedias incorrectas (codigo de color HEX RGB)"}
# @markdown Es el color al que cambiaran las respuestas intermedias cuando sean incorrectas.<br>

# @markdown    ######          `Ejemplos :FF0000`(rojo)<br>  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;```00FFFF``` (cian)

# @markdown ---
Color_Escrito_Fuera = "FF6666" # @param {"type":"string","placeholder":"Introduce el color de los dígitos escritos fuera de luegar (codigo de color HEX RGB)"}
# @markdown Es el color al que cambiara lo escrito fuera de sitio (sólo funciona en divisines con restas).<br>

# @markdown    ######          `Ejemplos :FF6666`(rojo claro )<br>  &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;```0000FF``` (azul)

# @markdown ---











#Modos_Disponibles="Fácil,Pro"


#Modo_Seleccionado="SuperPro"


# Lineas_de_restas_auxiliares_en_divisiones_siempre_visibles=False

# Minimo_celdas_por_operacion=4     #poner 4 por lo mmenso




##Color_Respuesta_Final_Correcta='2EFE2E'    #2EFE2E darkgreen (el de la primera versin)

## Color_Respuesta_Intermedia_Correcta='04B431'    #E0F8E6 green (el de la lprimera version) (afecta a tinta pero facilmente cambiable a fondo)

# Color_Respuesta_Intermedia_Incorrecta='FF0000'    #'FF0000' rojo

# Color_Escrito_Fuera='FF6666'   # escrito fuera de sitio rojo claro FF6666





repo='MATOPE_COLAB'

import os
if not os.path.isdir(repo):
  # !git clone "https://github.com/agustinldg/{repo}.git"
import sys
sys.path.append('/content/'+repo)
import builtins
import re











builtins.CFG_NOMBRE_FICHERO=Nombre_de_la_hoja_Excel
builtins.CFG_OPERACIONES =Lista_de_operaciones

builtins.CFG_FONT_SIZE =Tamano_tipo_de_letra

builtins.CFG_MODOS_DISPO=Modos_de_Resolucion_Disponibles
builtins.CFG_MODO_SELEC=Modo_Inicial_Seleccionado


builtins.CFG_COLOR_FINAL_OK=Color_Respuesta_Final_Correcta
builtins.CFG_COLOR_INTERMEDIO_OK=Color_Respuesta_Intermedia_Correcta


builtins.CFG_COLOR_INTERMEDIO_KO=Color_Respuesta_Intermedia_Incorrecta
builtins.CFG_COLOR_ESCRITO_FUERA=Color_Escrito_Fuera




builtins.CFG_OPERACIONES_POR_FILA=Numero_de_columnas_de_operaciones


builtins.CFG_MIN_CELDAS_POR_OPERACION=Minimo_celdas_por_operacion

builtins.CFG_LINEAS_RESTA_AUX_DIVI_FIJAS=Lineas_de_restas_auxiliares_en_divisiones_siempre_visibles

builtins.CFG_MARGEN_DERECHO=20




builtins.CFG_MARGEN_X=4
builtins.CFG_MARGEN_Y=3

builtins.CFg_USER="COLAB_MATOPE_v2.1"


test_CFG_COLOR_FINAL_OK=bool(re.match(r"^[A-Fa-f0-9]{6}$", CFG_COLOR_FINAL_OK))
test_CFG_COLOR_INTERMEDIO_OK=bool(re.match(r"^[A-Fa-f0-9]{6}$", CFG_COLOR_INTERMEDIO_OK))



test_CFG_COLOR_FINAL_OK=bool(re.match(r"^[A-Fa-f0-9]{6}$", CFG_COLOR_FINAL_OK))
test_CFG_COLOR_INTERMEDIO_OK=bool(re.match(r"^[A-Fa-f0-9]{6}$", CFG_COLOR_INTERMEDIO_OK))
test_CFG_COLOR_INTERMEDIO_KO=bool(re.match(r"^[A-Fa-f0-9]{6}$", CFG_COLOR_INTERMEDIO_KO))
test_CFG_COLOR_ESCRITO_FUERA=bool(re.match(r"^[A-Fa-f0-9]{6}$", CFG_COLOR_ESCRITO_FUERA))


from crea_hoja import crea_hoja
from google.colab import files


if  test_CFG_COLOR_FINAL_OK and test_CFG_COLOR_INTERMEDIO_OK and test_CFG_COLOR_INTERMEDIO_KO and test_CFG_COLOR_ESCRITO_FUERA :
    crea_hoja()
    files.download(Nombre_de_la_hoja_Excel+'.xlsx')
else:
    print ('')
    print (f'ERROR EN LA DEFINICION de "Color_Respuesta_Final_Correcta" = {CFG_COLOR_FINAL_OK} ' if not test_CFG_COLOR_FINAL_OK else "" )
    print (f'ERROR EN LA DEFINICION de "Color_Respuesta_Intermedia_Correcta" = {CFG_COLOR_INTERMEDIO_OK} ' if not test_CFG_COLOR_INTERMEDIO_OK else "" )
    print (f'ERROR EN LA DEFINICION de "Color_Respuesta_Intermedia_Incorrecta" = {CFG_COLOR_INTERMEDIO_KO} ' if not test_CFG_COLOR_INTERMEDIO_KO else "" )
    print (f'ERROR EN LA DEFINICION de "Color_Escrito_Fuera = {CFG_COLOR_ESCRITO_FUERA} ' if not test_CFG_COLOR_ESCRITO_FUERA else "" )

    print ('Los colores se definen con 6 carácteres de 0 a 9 ó de A a F.  Ejemplo 2EFE2E')
    print ('Vuelve a ejecutar el proceso despues hacer la correción')
    print ('')
# Out:
# <operacion.Division_con_restas object at 0x7ba5a1c2e6e0> [2456, 2] --> OK
# <operacion.Division object at 0x7ba5a1c2ead0> [3578, 3] --> OK
# <operacion.Division object at 0x7ba5a25c48e0> [5678, 4] --> OK
# <operacion.Division_con_restas object at 0x7ba5a25c5060> [8932, 5] --> OK
# <operacion.Suma object at 0x7ba5a25c5000> [14, 11, 27, 28] --> OK
# Usage archivado OK
# Hoja de Cálculo generada.
